# %%
import pandas as pd
import numpy as np
import os

# %%
root = '/home/giovannyencinia/Documents/datasets/MACHINE_LEARNING_course'
path = root + '/wine/winequality-red.csv'
path_w = root + '/wine/winequality-white.csv'
df_winer = pd.read_csv(path, sep =';')
df_winew = pd.read_csv(path_w, sep=';')
df_winew
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df_wine = pd.concat([df_winer, df_winew], axis = 0)
df_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# # Datos Distribuidos

# %%
file_path = root + '/distributed-data'
df = file_path + '001.csv'

with os.scandir(file_path) as files:
    df = pd.DataFrame()
    for file in files:
        df_temp = pd.read_csv(file_path + '/' + file.name)
        d = df_temp
        df = pd.concat([df, df_temp])

# %%
df = df.sort_values('ID')

# %%
df = df.set_index(np.arange(df.shape[0]))

# %%
df
# Out:
#               Date  sulfate  nitrate   ID
# 0       2005-12-31      NaN      NaN    1
# 1       2004-08-21      NaN      NaN    1
# 2       2004-08-22      NaN      NaN    1
# 3       2004-08-23      NaN      NaN    1
# 4       2004-08-24      NaN      NaN    1
# ...            ...      ...      ...  ...
# 772082  2003-09-10      NaN      NaN  332
# 772083  2003-09-11      NaN      NaN  332
# 772084  2003-09-12      NaN      NaN  332
# 772085  2003-09-14      NaN      NaN  332
# 772086  2003-01-01      NaN      NaN  332
#
# [772087 rows x 4 columns]

# %% [markdown]
# # Merge

# %%
path = root + '/athletes'
df_main = pd.read_csv(path + '/Medals.csv', encoding = 'ISO-8859-1')
df_country = pd.read_csv(path + '/Athelete_Country_Map.csv', encoding='ISO-8859-1')
df_sport = pd.read_csv(path+ '/Athelete_Sports_Map.csv', encoding='ISO-8859-1')

# %%
df_country_dp = df_country.drop_duplicates('Athlete')
df_sport_dp = df_sport.drop_duplicates('Athlete')
df_main_country = pd.merge(left = df_main, right = df_country_dp,
                           on='Athlete')
df_olimpics = pd.merge(left=df_main_country, right=df_sport_dp, 
                       on='Athlete')

# %%
df_olimpics
# Out:
#                    Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0           Michael Phelps  23.0  2008            08/24/2008            8
# 1           Michael Phelps  19.0  2004            08/29/2004            6
# 2           Michael Phelps  27.0  2012            08/12/2012            4
# 3         Natalie Coughlin  25.0  2008            08/24/2008            1
# 4         Natalie Coughlin  21.0  2004            08/29/2004            2
# ...                    ...   ...   ...                   ...          ...
# 8613      Olena Sadovnycha  32.0  2000            10/01/2000            0
# 8614      Kateryna Serdiuk  17.0  2000            10/01/2000            0
# 8615      Wietse van Alten  21.0  2000            10/01/2000            0
# 8616  Sandra Wagner-Sachse  31.0  2000            10/01/2000            0
# 8617             Rod White  23.0  2000            10/01/2000            0
#
#       Silver Medals  Bronze Medals  Total Medals        Country     Sport
# ...

# %%
df_main
# Out:
#                    Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0           Michael Phelps  23.0  2008            08/24/2008            8
# 1           Michael Phelps  19.0  2004            08/29/2004            6
# 2           Michael Phelps  27.0  2012            08/12/2012            4
# 3         Natalie Coughlin  25.0  2008            08/24/2008            1
# 4            Aleksey Nemov  24.0  2000            10/01/2000            2
# ...                    ...   ...   ...                   ...          ...
# 8613      Olena Sadovnycha  32.0  2000            10/01/2000            0
# 8614      Kateryna Serdiuk  17.0  2000            10/01/2000            0
# 8615      Wietse van Alten  21.0  2000            10/01/2000            0
# 8616  Sandra Wagner-Sachse  31.0  2000            10/01/2000            0
# 8617             Rod White  23.0  2000            10/01/2000            0
#
#       Silver Medals  Bronze Medals  Total Medals
# ...

# %%
df_sport
# Out:
#                    Athlete       Sport
# 0           Michael Phelps    Swimming
# 1         Natalie Coughlin    Swimming
# 2            Aleksey Nemov  Gymnastics
# 3            Alicia Coutts    Swimming
# 4           Missy Franklin    Swimming
# ...                    ...         ...
# 6970      Olena Sadovnycha     Archery
# 6971      Kateryna Serdiuk     Archery
# 6972      Wietse van Alten     Archery
# 6973  Sandra Wagner-Sachse     Archery
# 6974             Rod White     Archery
#
# [6975 rows x 2 columns]

# %%
df_main
# Out:
#                    Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0           Michael Phelps  23.0  2008            08/24/2008            8
# 1           Michael Phelps  19.0  2004            08/29/2004            6
# 2           Michael Phelps  27.0  2012            08/12/2012            4
# 3         Natalie Coughlin  25.0  2008            08/24/2008            1
# 4            Aleksey Nemov  24.0  2000            10/01/2000            2
# ...                    ...   ...   ...                   ...          ...
# 8613      Olena Sadovnycha  32.0  2000            10/01/2000            0
# 8614      Kateryna Serdiuk  17.0  2000            10/01/2000            0
# 8615      Wietse van Alten  21.0  2000            10/01/2000            0
# 8616  Sandra Wagner-Sachse  31.0  2000            10/01/2000            0
# 8617             Rod White  23.0  2000            10/01/2000            0
#
#       Silver Medals  Bronze Medals  Total Medals
# ...
