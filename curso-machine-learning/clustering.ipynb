# %% [markdown]
# # Distancias

# %%
from scipy.spatial import distance_matrix
import pandas as pd

# %%
root = '/home/giovannyencinia/Documents/datasets/MACHINE_LEARNING_course'
path = root + '/movies/movies.csv'
df_movies = pd.read_csv(path, sep=';')
df_movies.head()
# Out:
#    user_id  star_wars  lord_of_the_rings  harry_potter
# 0        1        1.2                4.9           2.1
# 1        2        2.1                8.1           7.9
# 2        3        7.4                3.0           9.9
# 3        4        5.6                0.5           1.8
# 4        5        1.5                8.3           2.6

# %%
columns = df_movies.columns.values.tolist()
columns
# Out:
# ['user_id', 'star_wars', 'lord_of_the_rings', 'harry_potter']

# %%
dd1 = distance_matrix(df_movies[columns], df_movies[columns], p=1 )
dd2 = distance_matrix(df_movies[columns], df_movies[columns], p=2 )
dd3 = distance_matrix(df_movies[columns], df_movies[columns], p=10 )

# %%
def toDataFrame(matrix, col):
    import pandas as pd
    return pd.DataFrame(matrix, index=col, columns=col)

# %%
dd1 = toDataFrame(dd1, df_movies['user_id'])

# %% [markdown]
# ## Jugando matplotlib

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

# %%
fig = plt.figure('clasic')
ax = fig.add_subplot(111, projection='3d')
ax.scatter(xs=df_movies['star_wars'], ys=df_movies['lord_of_the_rings'], 
           zs=df_movies['harry_potter']);

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)
plt.scatter(x, y, c=colors, s=sizes, alpha=0.5,
cmap='viridis')
plt.colorbar();

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np
x = np.linspace(0, 10, 50)
dy = 0.5
y = np.sin(x) + dy * np.random.randn(50)
plt.plot(x, np.sin(x))
plt.errorbar(x, y, yerr=.5, fmt='.k');

# %%
def hist_and_lines():
    np.random.seed(0)
    fig, ax = plt.subplots(1, 2, figsize=(11, 4))
    ax[0].hist(np.random.randn(1000))
    for i in range(3):
        ax[1].plot(np.random.rand(10))
        ax[1].legend(['a', 'b', 'c'], loc='lower left')
        
with plt.style.context('fivethirtyeight'):
    hist_and_lines()

# %%
with plt.style.context('ggplot'):
    hist_and_lines()

# %% [markdown]
# # Uniendo datos manualmente

# %%
df_movies.loc[0]
# Out:
# user_id              1.0
# star_wars            1.2
# lord_of_the_rings    4.9
# harry_potter         2.1
# Name: 0, dtype: float64
